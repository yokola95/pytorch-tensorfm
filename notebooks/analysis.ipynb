# %%
import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print(pd.__version__)
# Out:
# 2.2.1

# %%
files = glob.glob('../data/optuna_results*.txt')
columns = 'Study,model name,metric to optimize,rank,embed. size,learning rate,optimizer,batch size,return_L2,coef vectors,coef biases,"part id",trial number,epoch number,train loss,train auc,validation loss,validation auc,test loss,test auc,epoch train time,validation time,criterion,dataset'.split(',')

# %%
dfs = []
for file in files:
  print(f'Loading {file}')
  dfs.append(pd.read_csv(file, names=columns))
df = pd.concat(dfs, axis=0, ignore_index=True)
df.head()
# Out:
# Loading ../data/optuna_results.txt
#                             Study   model name metric to optimize  rank  \
# 0   Study pruned_fwfm logloss 1 8  pruned_fwfm            logloss     1
# 1   Study pruned_fwfm logloss 4 8  pruned_fwfm            logloss     4
# 2  Study pruned_fwfm logloss 3 16  pruned_fwfm            logloss     3
# 3   Study pruned_fwfm logloss 3 8  pruned_fwfm            logloss     3
# 4  Study pruned_fwfm logloss 4 16  pruned_fwfm            logloss     4
#
#    embed. size  learning rate optimizer  batch size  return_L2  coef vectors  \
# 0            8       0.001723   adagrad        1024       True      0.000095
# 1            8       0.001723   adagrad        1024       True      0.000095
# 2           16       0.001723   adagrad        1024       True      0.000095
# 3            8       0.001723   adagrad        1024       True      0.000095
# 4           16       0.001723   adagrad        1024       True      0.000095
#
#    ...  trial number  epoch number  validation loss  validation auc  \
# 0  ...             0             0         0.483627        0.741341
# 1  ...             0             0         0.424057        0.744801
# 2  ...             0             0         0.440976        0.742753
# 3  ...             0             0         0.436348        0.743615
# 4  ...             0             0         0.426121        0.745695
#
#    test loss  test auc  epoch train time  validation time     criterion  \
# 0   0.483071  0.742091        126.303244         1.884501  bcelogitloss
# 1   0.423299  0.745406        126.634219         1.978106  bcelogitloss
# 2   0.440213  0.743586        128.269160         1.955984  bcelogitloss
# 3   0.435627  0.744242        127.855864         1.788292  bcelogitloss
# 4   0.425330  0.746411        130.938987         1.779484  bcelogitloss
#
#    dataset
# 0    avazu
# 1    avazu
# 2    avazu
# 3    avazu
# 4    avazu
#
# [5 rows x 22 columns]

# %%
datasets = df['dataset'].unique()
datasets
# Out:
# array(['avazu', 'criteo', 'movielens'], dtype=object)

# %%
experiment_cols = ['dataset', 'metric to optimize', 'model name', 'rank', 'embed. size']

def best_config_test_metric(group):
  if group['metric to optimize'].iloc[0] == 'auc':
    costs = group[['validation auc', 'test auc']]
    agg = pd.Series.idxmax
  else:
    costs = group[['validation loss', 'test loss']]
    agg = pd.Series.idxmin
  costs.columns = ['validation', 'test']

  idx_opt = agg(costs['validation'])
  opt = costs.loc[idx_opt, 'test']
  return pd.Series([opt], name='test loss').to_frame()

test_loss_df = df \
  .groupby(experiment_cols).apply(best_config_test_metric) \
  .reset_index() \
  .set_index('dataset')
# Out:
# /var/folders/vd/1vmnh86s29zf8_b8s7_vl_xc0000gq/T/ipykernel_45544/3153446575.py:17: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .groupby(experiment_cols).apply(best_config_test_metric) \

# %%
def dataset_summary(df, name, zero_rank_models=['fm', 'fwfm']):
  # extract only relevant dataset
  df = df.loc[name, :]

  # replicate FM / FwFM results across all ranks.
  max_rank = df['rank'].max()
  replicated_ranks = df[df['model name'].isin(zero_rank_models)] \
    .drop('rank', axis=1) \
    .merge(pd.DataFrame({'rank': np.arange(1, 1 + max_rank)}), how='cross')
  to_pivot = pd.concat([df, replicated_ranks], axis=0)
  to_pivot = to_pivot[to_pivot['rank'] > 0]


  # create pivoted frame with readable model names
  to_pivot.replace({
      'fm': 'FM',
      'fwfm': 'FwFM',
      'lowrank_fwfm': 'DPLR',
      'pruned_fwfm': 'Pruned',
      'logloss': 'LogLoss',
      'auc': 'AUC',
      'mse': 'MSE'
  }, inplace=True)
  pivoted = to_pivot.pivot(
      index=['metric to optimize', 'rank'],
      columns=['embed. size', 'model name'],
      values='test loss'
  )

  # compute lifts and concatenate to the pivoted DF
  pruned = pivoted.xs('Pruned', axis=1, level=1)
  dplr = pivoted.xs('DPLR', axis=1, level=1)
  lift = 100 * (1 - dplr / pruned)
  lift = pd.concat([lift], keys=['DPLR vs Pruned (%)'], names=['model name'], axis=1) \
    .reorder_levels([1, 0], axis=1)
  summary = pd.concat([pivoted, lift], axis=1)

  # invert AUC lift sign
  if 'AUC' in summary.index.levels[0]:
    summary.loc[pd.IndexSlice['AUC', :], pd.IndexSlice[:, 'DPLR vs Pruned (%)']] *= -1

  # make sure models are displayed in the correct order using a categotical variable
  model_name_cat = pd.CategoricalIndex(pd.Categorical(
      summary.columns.levels[1],
      categories=['FM', 'FwFM', 'DPLR', 'Pruned', 'DPLR vs Pruned (%)'],
      ordered=True
  ))
  summary.columns = summary.columns.set_levels(model_name_cat, level=1)
  return summary.sort_index(axis=1)

# %%
criteo_summary = dataset_summary(test_loss_df, 'criteo')
criteo_summary
# Out:
# embed. size                    8                                 \
# model name                     FM      FwFM      DPLR    Pruned
# metric to optimize rank
# AUC                1     0.804394  0.808756  0.805015  0.800813
#                    2     0.804394  0.808756  0.806559  0.804859
#                    3     0.804394  0.808756  0.806686  0.806540
#                    4     0.804394  0.808756  0.806922  0.807364
#                    5     0.804394  0.808756  0.807050  0.807846
# LogLoss            1     0.447040  0.442922  0.446662  0.451023
#                    2     0.447040  0.442922  0.445366  0.446897
#                    3     0.447040  0.442922  0.445023  0.445076
#                    4     0.447040  0.442922  0.444287  0.444290
#                    5     0.447040  0.442922  0.444274  0.443850
#
# embed. size                                       16                      \
# model name              DPLR vs Pruned (%)        FM      FwFM      DPLR
# metric to optimize rank
# AUC                1              0.524822  0.806853  0.809968  0.806890
#                    2              0.211297  0.806853  0.809968  0.808009
#                    3              0.018039  0.806853  0.809968  0.808292
#                    4             -0.054735  0.806853  0.809968  0.808504
#                    5             -0.098514  0.806853  0.809968  0.808544
# LogLoss            1              0.966807  0.444858  0.441737  0.444940
#                    2              0.342733  0.444858  0.441737  0.443676
#                    3              0.012057  0.444858  0.441737  0.443464
#                    4              0.000632  0.444858  0.441737  0.443136
#                    5             -0.095355  0.444858  0.441737  0.442966
#
# embed. size
# model name                 Pruned DPLR vs Pruned (%)
# metric to optimize rank
# AUC                1     0.802036           0.605220
#                    2     0.805707           0.285748
#                    3     0.807591           0.086795
#                    4     0.808598          -0.011566
#                    5     0.809122          -0.071441
# LogLoss            1     0.450780           1.295645
#                    2     0.446357           0.600684
#                    3     0.444398           0.209994
#                    4     0.443128          -0.001889
#                    5     0.442633          -0.075349

# %%
avazu_summary = dataset_summary(test_loss_df, 'avazu')
avazu_summary
# Out:
# embed. size                    8                                 \
# model name                     FM      FwFM      DPLR    Pruned
# metric to optimize rank
# AUC                1     0.776783  0.777658  0.776427  0.772667
#                    2     0.776783  0.777658  0.776881  0.775609
#                    3     0.776783  0.777658  0.777204  0.776399
#                    4     0.776783  0.777658  0.777189  0.776989
#                    5     0.776783  0.777658  0.777406  0.777409
# LogLoss            1     0.381060  0.380832  0.381731  0.384127
#                    2     0.381060  0.380832  0.381227  0.381658
#                    3     0.381060  0.380832  0.381152  0.381434
#                    4     0.381060  0.380832  0.381030  0.381054
#                    5     0.381060  0.380832  0.381128  0.380951
#
# embed. size                                       16                      \
# model name              DPLR vs Pruned (%)        FM      FwFM      DPLR
# metric to optimize rank
# AUC                1              0.486546  0.778747  0.779638  0.777647
#                    2              0.164003  0.778747  0.779638  0.778369
#                    3              0.103748  0.778747  0.779638  0.778922
#                    4              0.025683  0.778747  0.779638  0.778941
#                    5             -0.000291  0.778747  0.779638  0.778790
# LogLoss            1              0.623622  0.379962  0.379543  0.380980
#                    2              0.113164  0.379962  0.379543  0.380140
#                    3              0.074136  0.379962  0.379543  0.380091
#                    4              0.006321  0.379962  0.379543  0.380039
#                    5             -0.046660  0.379962  0.379543  0.380012
#
# embed. size
# model name                 Pruned DPLR vs Pruned (%)
# metric to optimize rank
# AUC                1     0.773817           0.494951
#                    2     0.777949           0.053916
#                    3     0.778917           0.000559
#                    4     0.779392          -0.057969
#                    5     0.779575          -0.100741
# LogLoss            1     0.382962           0.517455
#                    2     0.380221           0.021232
#                    3     0.380006          -0.022293
#                    4     0.379589          -0.118611
#                    5     0.379613          -0.105311

# %%
movielens_summary = dataset_summary(test_loss_df, 'movielens')
movielens_summary
# Out:
# embed. size                    8                                 \
# model name                     FM      FwFM      DPLR    Pruned
# metric to optimize rank
# MSE                1     0.743063  0.740681  0.744942  0.757160
#                    2     0.743063  0.740681  0.741755  0.746361
#
# embed. size                                       16                      \
# model name              DPLR vs Pruned (%)        FM      FwFM      DPLR
# metric to optimize rank
# MSE                1              1.613638  0.737641  0.739397  0.744478
#                    2              0.617136  0.737641  0.739397  0.739783
#
# embed. size
# model name                 Pruned DPLR vs Pruned (%)
# metric to optimize rank
# MSE                1     0.763012           2.429088
#                    2     0.748384           1.149391

# %%
full_summary = pd.concat(
    [criteo_summary, avazu_summary, movielens_summary],
    keys=['Criteo', 'Avazu', 'Movielens'],
    names=['Dataset'],
    axis=0
)
lst = [(f'{dataset} ({metric})', rank) for dataset, metric, rank in full_summary.index]
full_summary.index = pd.MultiIndex.from_tuples(lst)

# %%
def make_pretty(styler):
  styler.format(precision=4)
  styler.format('{:.2f}%', subset=[(8, 'DPLR vs Pruned (%)'), (16, 'DPLR vs Pruned (%)')])
  return styler

full_summary.style.pipe(make_pretty)
# Out:
# <style type="text/css">
# </style>
# <table id="T_d43a4">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >embed. size</th>
#       <th id="T_d43a4_level0_col0" class="col_heading level0 col0" colspan="5">8</th>
#       <th id="T_d43a4_level0_col5" class="col_heading level0 col5" colspan="5">16</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level1" >model name</th>
#       <th id="T_d43a4_level1_col0" class="col_heading level1 col0" >FM</th>
#       <th id="T_d43a4_level1_col1" class="col_heading level1 col1" >FwFM</th>
#       <th id="T_d43a4_level1_col2" class="col_heading level1 col2" >DPLR</th>
#       <th id="T_d43a4_level1_col3" class="col_heading level1 col3" >Pruned</th>
#       <th id="T_d43a4_level1_col4" class="col_heading level1 col4" >DPLR vs Pruned (%)</th>
#       <th id="T_d43a4_level1_col5" class="col_heading level1 col5" >FM</th>
#       <th id="T_d43a4_level1_col6" class="col_heading level1 col6" >FwFM</th>
#       <th id="T_d43a4_level1_col7" class="col_heading level1 col7" >DPLR</th>
#       <th id="T_d43a4_level1_col8" class="col_heading level1 col8" >Pruned</th>
#       <th id="T_d43a4_level1_col9" class="col_heading level1 col9" >DPLR vs Pruned (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d43a4_level0_row0" class="row_heading level0 row0" rowspan="5">Criteo (AUC)</th>
#       <th id="T_d43a4_level1_row0" class="row_heading level1 row0" >1</th>
#       <td id="T_d43a4_row0_col0" class="data row0 col0" >0.8044</td>
#       <td id="T_d43a4_row0_col1" class="data row0 col1" >0.8088</td>
#       <td id="T_d43a4_row0_col2" class="data row0 col2" >0.8050</td>
#       <td id="T_d43a4_row0_col3" class="data row0 col3" >0.8008</td>
#       <td id="T_d43a4_row0_col4" class="data row0 col4" >0.52%</td>
#       <td id="T_d43a4_row0_col5" class="data row0 col5" >0.8069</td>
#       <td id="T_d43a4_row0_col6" class="data row0 col6" >0.8100</td>
#       <td id="T_d43a4_row0_col7" class="data row0 col7" >0.8069</td>
#       <td id="T_d43a4_row0_col8" class="data row0 col8" >0.8020</td>
#       <td id="T_d43a4_row0_col9" class="data row0 col9" >0.61%</td>
#     </tr>
#     <tr>
#       <th id="T_d43a4_level1_row1" class="row_heading level1 row1" >2</th>
#       <td id="T_d43a4_row1_col0" class="data row1 col0" >0.8044</td>
#       <td id="T_d43a4_row1_col1" class="data row1 col1" >0.8088</td>
#       <td id="T_d43a4_row1_col2" class="data row1 col2" >0.8066</td>
#       <td id="T_d43a4_row1_col3" class="data row1 col3" >0.8049</td>
#       <td id="T_d43a4_row1_col4" class="data row1 col4" >0.21%</td>
#       <td id="T_d43a4_row1_col5" class="data row1 col5" >0.8069</td>
#       <td id="T_d43a4_row1_col6" class="data row1 col6" >0.8100</td>
#       <td id="T_d43a4_row1_col7" class="data row1 col7" >0.8080</td>
#       <td id="T_d43a4_row1_col8" class="data row1 col8" >0.8057</td>
#       <td id="T_d43a4_row1_col9" class="data row1 col9" >0.29%</td>
#     </tr>
#     <tr>
#       <th id="T_d43a4_level1_row2" class="row_heading level1 row2" >3</th>
#       <td id="T_d43a4_row2_col0" class="data row2 col0" >0.8044</td>
#       <td id="T_d43a4_row2_col1" class="data row2 col1" >0.8088</td>
#       <td id="T_d43a4_row2_col2" class="data row2 col2" >0.8067</td>
#       <td id="T_d43a4_row2_col3" class="data row2 col3" >0.8065</td>
#       <td id="T_d43a4_row2_col4" class="data row2 col4" >0.02%</td>
#       <td id="T_d43a4_row2_col5" class="data row2 col5" >0.8069</td>
#       <td id="T_d43a4_row2_col6" class="data row2 col6" >0.8100</td>
#       <td id="T_d43a4_row2_col7" class="data row2 col7" >0.8083</td>
#       <td id="T_d43a4_row2_col8" class="data row2 col8" >0.8076</td>
#       <td id="T_d43a4_row2_col9" class="data row2 col9" >0.09%</td>
#     </tr>
#     <tr>
#       <th id="T_d43a4_level1_row3" class="row_heading level1 row3" >4</th>
#       <td id="T_d43a4_row3_col0" class="data row3 col0" >0.8044</td>
#       <td id="T_d43a4_row3_col1" class="data row3 col1" >0.8088</td>
#       <td id="T_d43a4_row3_col2" class="data row3 col2" >0.8069</td>
#       <td id="T_d43a4_row3_col3" class="data row3 col3" >0.8074</td>
#       <td id="T_d43a4_row3_col4" class="data row3 col4" >-0.05%</td>
#       <td id="T_d43a4_row3_col5" class="data row3 col5" >0.8069</td>
#       <td id="T_d43a4_row3_col6" class="data row3 col6" >0.8100</td>
#       <td id="T_d43a4_row3_col7" class="data row3 col7" >0.8085</td>
#       <td id="T_d43a4_row3_col8" class="data row3 col8" >0.8086</td>
#       <td id="T_d43a4_row3_col9" class="data row3 col9" >-0.01%</td>
#     </tr>
#     <tr>
#       <th id="T_d43a4_level1_row4" class="row_heading level1 row4" >5</th>
#       <td id="T_d43a4_row4_col0" class="data row4 col0" >0.8044</td>
#       <td id="T_d43a4_row4_col1" class="data row4 col1" >0.8088</td>
#       <td id="T_d43a4_row4_col2" class="data row4 col2" >0.8070</td>
#       <td id="T_d43a4_row4_col3" class="data row4 col3" >0.8078</td>
#       <td id="T_d43a4_row4_col4" class="data row4 col4" >-0.10%</td>
#       <td id="T_d43a4_row4_col5" class="data row4 col5" >0.8069</td>
#       <td id="T_d43a4_row4_col6" class="data row4 col6" >0.8100</td>
#       <td id="T_d43a4_row4_col7" class="data row4 col7" >0.8085</td>
#       <td id="T_d43a4_row4_col8" class="data row4 col8" >0.8091</td>
#       <td id="T_d43a4_row4_col9" class="data row4 col9" >-0.07%</td>
#     </tr>
#     <tr>
#       <th id="T_d43a4_level0_row5" class="row_heading level0 row5" rowspan="5">Criteo (LogLoss)</th>
#       <th id="T_d43a4_level1_row5" class="row_heading level1 row5" >1</th>
#       <td id="T_d43a4_row5_col0" class="data row5 col0" >0.4470</td>
#       <td id="T_d43a4_row5_col1" class="data row5 col1" >0.4429</td>
#       <td id="T_d43a4_row5_col2" class="data row5 col2" >0.4467</td>
#       <td id="T_d43a4_row5_col3" class="data row5 col3" >0.4510</td>
#       <td id="T_d43a4_row5_col4" class="data row5 col4" >0.97%</td>
#       <td id="T_d43a4_row5_col5" class="data row5 col5" >0.4449</td>
#       <td id="T_d43a4_row5_col6" class="data row5 col6" >0.4417</td>
#       <td id="T_d43a4_row5_col7" class="data row5 col7" >0.4449</td>
#       <td id="T_d43a4_row5_col8" class="data row5 col8" >0.4508</td>
#       <td id="T_d43a4_row5_col9" class="data row5 col9" >1.30%</td>
#     </tr>
#     <tr>
#       <th id="T_d43a4_level1_row6" class="row_heading level1 row6" >2</th>
#       <td id="T_d43a4_row6_col0" class="data row6 col0" >0.4470</td>
#       <td id="T_d43a4_row6_col1" class="data row6 col1" >0.4429</td>
#       <td id="T_d43a4_row6_col2" class="data row6 col2" >0.4454</td>
#       <td id="T_d43a4_row6_col3" class="data row6 col3" >0.4469</td>
#       <td id="T_d43a4_row6_col4" class="data row6 col4" >0.34%</td>
#       <td id="T_d43a4_row6_col5" class="data row6 col5" >0.4449</td>
#       <td id="T_d43a4_row6_col6" class="data row6 col6" >0.4417</td>
#       <td id="T_d43a4_row6_col7" class="data row6 col7" >0.4437</td>
#       <td id="T_d43a4_row6_col8" class="data row6 col8" >0.4464</td>
#       <td id="T_d43a4_row6_col9" class="data row6 col9" >0.60%</td>
#     </tr>
#     <tr>
#       <th id="T_d43a4_level1_row7" class="row_heading level1 row7" >3</th>
#       <td id="T_d43a4_row7_col0" class="data row7 col0" >0.4470</td>
#       <td id="T_d43a4_row7_col1" class="data row7 col1" >0.4429</td>
#       <td id="T_d43a4_row7_col2" class="data row7 col2" >0.4450</td>
#       <td id="T_d43a4_row7_col3" class="data row7 col3" >0.4451</td>
#       <td id="T_d43a4_row7_col4" class="data row7 col4" >0.01%</td>
#       <td id="T_d43a4_row7_col5" class="data row7 col5" >0.4449</td>
#       <td id="T_d43a4_row7_col6" class="data row7 col6" >0.4417</td>
#       <td id="T_d43a4_row7_col7" class="data row7 col7" >0.4435</td>
#       <td id="T_d43a4_row7_col8" class="data row7 col8" >0.4444</td>
#       <td id="T_d43a4_row7_col9" class="data row7 col9" >0.21%</td>
#     </tr>
#     <tr>
#       <th id="T_d43a4_level1_row8" class="row_heading level1 row8" >4</th>
#       <td id="T_d43a4_row8_col0" class="data row8 col0" >0.4470</td>
#       <td id="T_d43a4_row8_col1" class="data row8 col1" >0.4429</td>
#       <td id="T_d43a4_row8_col2" cl

# %%
latex_code = full_summary.style.pipe(make_pretty).to_latex(multirow_align='t', hrules=True).replace('%', '\\%')
print(latex_code)
# Out:
# \begin{tabular}{llrrrrrrrrrr}
# \toprule
#  & embed. size & \multicolumn{5}{r}{8} & \multicolumn{5}{r}{16} \\
#  & model name & FM & FwFM & DPLR & Pruned & DPLR vs Pruned (\%) & FM & FwFM & DPLR & Pruned & DPLR vs Pruned (\%) \\
# \midrule
# \multirow[t]{5}{*}{Criteo (AUC)} & 1 & 0.8044 & 0.8088 & 0.8050 & 0.8008 & 0.52\% & 0.8069 & 0.8100 & 0.8069 & 0.8020 & 0.61\% \\
#  & 2 & 0.8044 & 0.8088 & 0.8066 & 0.8049 & 0.21\% & 0.8069 & 0.8100 & 0.8080 & 0.8057 & 0.29\% \\
#  & 3 & 0.8044 & 0.8088 & 0.8067 & 0.8065 & 0.02\% & 0.8069 & 0.8100 & 0.8083 & 0.8076 & 0.09\% \\
#  & 4 & 0.8044 & 0.8088 & 0.8069 & 0.8074 & -0.05\% & 0.8069 & 0.8100 & 0.8085 & 0.8086 & -0.01\% \\
#  & 5 & 0.8044 & 0.8088 & 0.8070 & 0.8078 & -0.10\% & 0.8069 & 0.8100 & 0.8085 & 0.8091 & -0.07\% \\
# \multirow[t]{5}{*}{Criteo (LogLoss)} & 1 & 0.4470 & 0.4429 & 0.4467 & 0.4510 & 0.97\% & 0.4449 & 0.4417 & 0.4449 & 0.4508 & 1.30\% \\
#  & 2 & 0.4470 & 0.4429 & 0.4454 & 0.4469 & 0.34\% & 0.4449 & 0.4417 & 0.4437 & 0.4464 & 0.60\% \\
#  & 3 & 0.4470 & 0.4429 & 0.4450 & 0.4451 & 0.01\% & 0.4449 & 0.4417 & 0.4435 & 0.4444 & 0.21\% \\
#  & 4 & 0.4470 & 0.4429 & 0.4443 & 0.4443 & 0.00\% & 0.4449 & 0.4417 & 0.4431 & 0.4431 & -0.00\% \\
#  & 5 & 0.4470 & 0.4429 & 0.4443 & 0.4439 & -0.10\% & 0.4449 & 0.4417 & 0.4430 & 0.4426 & -0.08\% \\
# \multirow[t]{5}{*}{Avazu (AUC)} & 1 & 0.7768 & 0.7777 & 0.7764 & 0.7727 & 0.49\% & 0.7787 & 0.7796 & 0.7776 & 0.7738 & 0.49\% \\
#  & 2 & 0.7768 & 0.7777 & 0.7769 & 0.7756 & 0.16\% & 0.7787 & 0.7796 & 0.7784 & 0.7779 & 0.05\% \\
#  & 3 & 0.7768 & 0.7777 & 0.7772 & 0.7764 & 0.10\% & 0.7787 & 0.7796 & 0.7789 & 0.7789 & 0.00\% \\
#  & 4 & 0.7768 & 0.7777 & 0.7772 & 0.7770 & 0.03\% & 0.7787 & 0.7796 & 0.7789 & 0.7794 & -0.06\% \\
#  & 5 & 0.7768 & 0.7777 & 0.7774 & 0.7774 & -0.00\% & 0.7787 & 0.7796 & 0.7788 & 0.7796 & -0.10\% \\
# \multirow[t]{5}{*}{Avazu (LogLoss)} & 1 & 0.3811 & 0.3808 & 0.3817 & 0.3841 & 0.62\% & 0.3800 & 0.3795 & 0.3810 & 0.3830 & 0.52\% \\
#  & 2 & 0.3811 & 0.3808 & 0.3812 & 0.3817 & 0.11\% & 0.3800 & 0.3795 & 0.3801 & 0.3802 & 0.02\% \\
#  & 3 & 0.3811 & 0.3808 & 0.3812 & 0.3814 & 0.07\% & 0.3800 & 0.3795 & 0.3801 & 0.3800 & -0.02\% \\
#  & 4 & 0.3811 & 0.3808 & 0.3810 & 0.3811 & 0.01\% & 0.3800 & 0.3795 & 0.3800 & 0.3796 & -0.12\% \\
#  & 5 & 0.3811 & 0.3808 & 0.3811 & 0.3810 & -0.05\% & 0.3800 & 0.3795 & 0.3800 & 0.3796 & -0.11\% \\
# \multirow[t]{2}{*}{Movielens (MSE)} & 1 & 0.7431 & 0.7407 & 0.7449 & 0.7572 & 1.61\% & 0.7376 & 0.7394 & 0.7445 & 0.7630 & 2.43\% \\
#  & 2 & 0.7431 & 0.7407 & 0.7418 & 0.7464 & 0.62\% & 0.7376 & 0.7394 & 0.7398 & 0.7484 & 1.15\% \\
# \bottomrule
# \end{tabular}
